# %%
x = 10

# %%
x
# Out:
# 10

# %%
y = 10

# %%
x = y + 2

# %%
x
# Out:
# 12

# %% [markdown]
# ## This is some title text
# Bla bla bla

# %%
def add(a,b):
    return a + b

# %%
add(10, 12)
# Out:
# 22

# %%
print(f'The result is {add(2,3)}')
# Out:
# The result is 5
