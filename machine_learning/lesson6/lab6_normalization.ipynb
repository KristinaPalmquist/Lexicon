# %% [markdown]
# # Lab 6
# We have now had the opportunity to explore and experiment with scikit-learn, a powerful machine learning library in Python. In this lab, we specifically used the KNeighborsClassifier along with train_test_split to build and evaluate a basic classification model. This hands-on experience gave us a glimpse into how machine learning workflows operate, from data preparation to training and testing.
# Although we managed to get a model up and running, there is definitely room for improvement in our test results. Today’s challenge is all about digging deeper and exploring different ways to influence and potentially improve the outcome of our model’s performance.
# Whether or not you actually succeed in improving the results is not the most important part. What truly matters is that you engage deeply with the process, try different ideas, and reflect on what happens and why.
# ## Some key questions to think about:
# Can we manipulate our data in a meaningful way to help the model learn better?
# Are there preprocessing steps we can add, such as normalization or feature scaling?
# How does changing parameters in KNeighborsClassifier affect the results?
# What impact does the way we split our data have on model accuracy?
# Use this time to experiment freely.
# ### Try:
# * Adjusting the number of neighbors (n_neighbors)
# * Using different values for test_size in train_test_split
# * Evaluating with cross_val_score instead of a single train/test split
# * Visualizing the data to see if there are patterns or outliers affecting performance
# Make sure to take notes on what you try, what changes you observe, and what you learn along the way. This is an excellent opportunity to develop your problem-solving skills and build intuition about machine learning models.##

# %% [markdown]
# ## Import the data

# %%
import pandas as pd

# %%
female_dataset = pd.read_csv('./data/female_sized.csv')
female_dataset.shape
# Out:
# (897, 5)

# %%
male_dataset = pd.read_csv('./data/male_sized.csv')
male_dataset.shape
# Out:
# (2144, 5)

# %% [markdown]
# ## Scikit-learn - Normalization

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score

male_X = male_dataset.drop(columns=['chestcircumference', 'biacromialbreadth', 't-shirt size'])
male_y = male_dataset['t-shirt size']
female_X = female_dataset.drop(columns=['chestcircumference', 'biacromialbreadth', 't-shirt size'])
female_y = female_dataset['t-shirt size']

k = 5
t = 0.2

male_X_train, male_X_test, male_y_train, male_y_test = train_test_split(male_X, male_y, test_size=t, random_state=42)

female_X_train, female_X_test, female_y_train, female_y_test = train_test_split(female_X, female_y, test_size=t, random_state=42)

# %%
print('Original - normalized')
male_scaler = MinMaxScaler()
male_X_train_scaled = male_scaler.fit_transform(male_X_train)
male_X_test_scaled = male_scaler.transform(male_X_test)
sk_clf = KNeighborsClassifier(n_neighbors=k)
sk_clf.fit(male_X_train_scaled, male_y_train)
predictions = sk_clf.predict(male_X_test_scaled)
accuracy = accuracy_score(male_y_test, predictions)
print(f'Male: k = {k}, t = {t}, Accuracy = {accuracy:.3f}')

female_scaler = MinMaxScaler()
female_X_train_scaled = female_scaler.fit_transform(female_X_train)
female_X_test_scaled = female_scaler.transform(female_X_test)
sk_clf = KNeighborsClassifier(n_neighbors=5)
sk_clf.fit(female_X_train_scaled, female_y_train)
predictions = sk_clf.predict(female_X_test_scaled)
accuracy = accuracy_score(female_y_test, predictions)
print(f'Female: k = {k}, t = {t}, Accuracy = {accuracy:.3f}')
# Out:
# Original - normalized
# Male: k = 5, t = 0.2, Accuracy = 0.580
# Female: k = 5, t = 0.2, Accuracy = 0.433

# %%
print('Test Size - normalized')
k = 5
for t in [0.1, 0.2, 0.3, 0.5]:
    X_train, X_test, y_train, y_test = train_test_split(male_X, male_y, test_size=t, random_state=42)
    scaler = MinMaxScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    sk_clf = KNeighborsClassifier(n_neighbors=5)
    sk_clf.fit(X_train_scaled, y_train)
    predictions = sk_clf.predict(X_test_scaled)
    accuracy = accuracy_score(y_test, predictions)
    print(f'Male: k = {k}, t = {t}: Accuracy = {accuracy:.3f}')

for t in [0.1, 0.2, 0.3, 0.5]:
    X_train, X_test, y_train, y_test = train_test_split(female_X, female_y, test_size=t, random_state=42)
    scaler = MinMaxScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    sk_clf = KNeighborsClassifier(n_neighbors=5)
    sk_clf.fit(X_train_scaled, y_train)
    predictions = sk_clf.predict(X_test_scaled)
    accuracy = accuracy_score(y_test, predictions)
    print(f'Female: k = {k}, t = {t}: Accuracy = {accuracy:.3f}')
# Out:
# Test Size - normalized
# Male: k = 5, t = 0.1: Accuracy = 0.609
# Male: k = 5, t = 0.2: Accuracy = 0.580
# Male: k = 5, t = 0.3: Accuracy = 0.559
# Male: k = 5, t = 0.5: Accuracy = 0.568
# Female: k = 5, t = 0.1: Accuracy = 0.444
# Female: k = 5, t = 0.2: Accuracy = 0.433
# Female: k = 5, t = 0.3: Accuracy = 0.441
# Female: k = 5, t = 0.5: Accuracy = 0.421

# %%
print('Neighbors - normalized')
t = 0.2
for k in [1, 3, 5, 7, 11, 15, 21]:
    sk_clf = KNeighborsClassifier(n_neighbors=k)
    sk_clf.fit(male_X_train_scaled, male_y_train)
    predictions = sk_clf.predict(male_X_test_scaled)
    accuracy = accuracy_score(male_y_test, predictions)
    print(f'Male: k = {k}, t = {t}, Accuracy = {accuracy:.3f}')
# Out:
# Neighbors - normalized
# Male: k = 1, t = 0.2, Accuracy = 0.490
# Male: k = 3, t = 0.2, Accuracy = 0.538
# Male: k = 5, t = 0.2, Accuracy = 0.580
# Male: k = 7, t = 0.2, Accuracy = 0.599
# Male: k = 11, t = 0.2, Accuracy = 0.599
# Male: k = 15, t = 0.2, Accuracy = 0.587
# Male: k = 21, t = 0.2, Accuracy = 0.604

# %%
print('Neighbors - normalized')
for k in [1, 3, 5, 7, 11, 15, 21]:
    sk_clf = KNeighborsClassifier(n_neighbors=k)
    sk_clf.fit(female_X_train_scaled, female_y_train)
    predictions = sk_clf.predict(female_X_test_scaled)
    accuracy = accuracy_score(female_y_test, predictions)
    print(f'Female: k = {k}, t = {t}, Accuracy = {accuracy:.3f}')
# Out:
# Neighbors - normalized
# Female: k = 1, t = 0.2, Accuracy = 0.372
# Female: k = 3, t = 0.2, Accuracy = 0.461
# Female: k = 5, t = 0.2, Accuracy = 0.433
# Female: k = 7, t = 0.2, Accuracy = 0.439
# Female: k = 11, t = 0.2, Accuracy = 0.444
# Female: k = 15, t = 0.2, Accuracy = 0.456
# Female: k = 21, t = 0.2, Accuracy = 0.472

# %%
print('Cross-validation - normalized')
male_scaler = MinMaxScaler()
male_X_scaled = male_scaler.fit_transform(male_X)
sk_clf = KNeighborsClassifier(n_neighbors=5)
cv_scores = cross_val_score(sk_clf, male_X_scaled, male_y, cv=5)
print(f'Male: Accuracy = {cv_scores.mean():.3f} (+/- {cv_scores.std() * 2:.3f})')
female_scaler = MinMaxScaler()
female_X_scaled = female_scaler.fit_transform(female_X)
sk_clf = KNeighborsClassifier(n_neighbors=5)
cv_scores = cross_val_score(sk_clf, female_X_scaled, female_y, cv=5)
print(f'Female: Accuracy = {cv_scores.mean():.3f} (+/- {cv_scores.std() * 2:.3f})')
# Out:
# Cross-validation - normalized
# Male: Accuracy = 0.583 (+/- 0.018)
# Female: Accuracy = 0.489 (+/- 0.080)
